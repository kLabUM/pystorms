# %% [markdown]
# # UDS-RTC101: Test environment
# This notebook is for testing Google Colab on your browser.

# %%
# !pip install pyswmm pystorms numpy matplotlib

# %%
import pyswmm
import pystorms
import numpy as np
import matplotlib.pyplot as plt

# %%
pyswmm.__version__
# Out:
# '1.0.1'

# %%
pystorms.__version__
# Out:
# '0.6.0'

# %%
x = np.linspace(0, 2, 100) * np.pi
y = np.sin(x)
plt.plot(x, y)
